# %%
import numpy as np

Rc = 57.7e+04
wc = 22.0e-09
tc = 44.0e-09

rowcu = Rc * wc * tc


Wcu = np.linspace(50, 140, 100)
Tcu = np.linspace(10, 100, 100)

resistance_data = []

for width in Wcu:
    for thickness in Tcu:
        Wcu_m = width * 1e-9
        Tcu_m = thickness * 1e-9

        resistance = rowcu / (Tcu_m * Wcu_m)
        resistance_data.append([width, thickness, resistance])


np.savetxt("copper_resistance_data.csv", resistance_data, delimiter=",", header="Width (nm), Thickness (nm), Resistance (Ohms)", fmt='%f, %f, %.4e', comments='')

# %%
import pandas as pd

# %%
df= pd.read_csv('/content/copper_resistance_data.csv')
df
# Out:
#       Width (nm)   Thickness (nm)   Resistance (Ohms)
# 0           50.0        10.000000           1117100.0
# 1           50.0        10.909091           1024000.0
# 2           50.0        11.818182            945210.0
# 3           50.0        12.727273            877700.0
# 4           50.0        13.636364            819190.0
# ...          ...              ...                 ...
# 9995       140.0        96.363636             41401.0
# 9996       140.0        97.272727             41014.0
# 9997       140.0        98.181818             40634.0
# 9998       140.0        99.090909             40261.0
# 9999       140.0       100.000000             39895.0
#
# [10000 rows x 3 columns]
